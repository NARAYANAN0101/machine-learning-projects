# %%
import pandas as pd

# %%
dataset=pd.read_csv('/content/chennai_rainfall_2019_2023_mm.csv')

# %%
dataset
# Out:
#             Date  Year  Month  Temperature (°C)  Humidity (%)  \
# 0     2019-01-01  2019      1              31.0          74.5
# 1     2019-01-02  2019      1              29.7          87.1
# 2     2019-01-03  2019      1              31.3          79.5
# 3     2019-01-04  2019      1              33.0          80.1
# 4     2019-01-05  2019      1              29.5          83.5
# ...          ...   ...    ...               ...           ...
# 1821  2023-12-27  2023     12              30.2          81.1
# 1822  2023-12-28  2023     12              29.6          83.9
# 1823  2023-12-29  2023     12              28.7          77.8
# 1824  2023-12-30  2023     12              30.3          82.0
# 1825  2023-12-31  2023     12              30.9          82.8
#
#       Wind Speed (km/h)  Rainfall (cm)  Rainfall (mm)
# 0                  13.3            0.5            5.0
# 1                   9.5            0.1            1.0
# 2                  12.4            0.3            3.0
# ...

# %%
independent=dataset[["Rainfall (cm)","Temperature (°C)","Humidity (%)"]]
dependent=dataset[["Wind Speed (km/h)"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=40)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predi=regressor.predict(x_test)

# %%
y_predi
# Out:
# array([11.7, 15.2, 17. , 12.7, 12.2,  7.7, 12.3, 13.1,  6.9, 13.6,  7.8,
#        14.2, 14.7, 11. , 12.7, 11. , 17.1, 10.6, 13. , 12.7, 11.6, 10.8,
#        19.6,  8.4,  8.5,  9.6, 13.3, 10.4, 12.3, 13.7, 11.1,  7.5, 11.9,
#        13.8,  6.8, 11.6, 11.5,  8.6, 12.2, 10.4, 11.6, 13.3,  8. ,  8.4,
#        15.2, 15.2, 17.1, 11.8, 10.2,  5.5, 11.5, 11.3, 14.6, 14.4, 10.5,
#         9.9, 10.3, 15. , 12.1,  7.2, 13.3,  8.5, 14.1,  6.6, 11.7, 13.5,
#        11.8,  8.6, 10.9,  9.8, 11.7, 12.9,  8.5, 10.6,  9.8, 10.9,  9.7,
#        10.2, 13.3, 15.4, 13.1, 10.1, 12.6,  7.2,  8.7,  9.3, 14.7,  9.2,
#        15.6, 11.3, 17.2, 11.9,  7.3, 11.4, 14.5, 13.3, 12.7, 12.3, 10.5,
#        10.2, 13.2, 16.4, 12.9, 11.8, 17.1, 12.9,  9.7, 11.7, 10.3, 11.5,
#        14.2,  9.9,  7.3, 10.1, 10.2, 13.5, 18.6, 12. ,  7.8,  9. , 12.2,
#        12.4, 11.5, 16.1, 11. ,  5.3,  8.8,  5.5, 14.3, 11.5, 15.4, 12.8,
#         8.9, 12.6,  9.9, 14.5,  8.9, 11.7, 14.8,  6.8, 13.1, 13.3,  8.9,
# ...

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_predi)

# %%
r_score
# Out:
# -0.8666778542283744
